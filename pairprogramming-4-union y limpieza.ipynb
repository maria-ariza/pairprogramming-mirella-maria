# %%
import pandas as pd

# %%
df1 = pd.read_csv('archivos/world-data-2023_part1.csv', index_col=0)

# %%
df2 = pd.read_csv('archivos/world-data-2023_part2.csv', index_col=0)

# %%
df1
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0          652,230           323,000       32.49          93.0
# ...

# %%
df2
# Out:
#                    GDP Gross primary education enrollment (%)  \
# 0     $19,101,353,833                                 104.00%
# 1     $15,278,077,447                                 107.00%
# 2    $169,988,236,398                                 109.90%
# 3      $3,154,057,987                                 106.40%
# 4     $94,635,415,870                                 113.50%
# ..                 ...                                    ...
# 190  $482,359,318,768                                  97.20%
# 191  $261,921,244,843                                 110.60%
# 192   $26,914,402,224                                  93.60%
# 193   $23,064,722,446                                  98.70%
# 194   $21,440,758,800                                 109.90%
#
#     Gross tertiary education enrollment (%)  Infant mortality  \
# 0                                     9.70%              47.9
# 1                                    55.00%               7.8
# ...

# %% [markdown]
# * Explicación
#
# Hemos usado .merge para unir df1 y df2, ya que son dos dataframes con el mismo número de filas pero distintas columnas, teniendo en común una de ellas. Para unirlos, aplicamos how='outer', esto quiere decir que el resultado es un dataframe con todo lo contenido en ambos dataframes, especificando las columnas por las que queremos unir, en este caso, 'Country' en df1 y 'country' en df2.

# %%
df = df1.merge(df2, how='outer', left_on='Country', right_on='country')

# %% [markdown]
# 1. Después de la unión de datos, tenemos dos columnas de "country". Elimina una de ellas.

# %%
df.drop('country', axis=1, inplace=True)

# %% [markdown]
# 2. Los nombres de las columnas no son homogeneos. Cambia los nombres de las columnas de tal forma que:
#
# No tengan espacios.
#
# Estén en minúscula.
#
# No tengan paréntesis, es decir, quitar "(%)", "(Km2)".
#
# Algunas columnas tiene "\n". Eliminalos de los nombres de las columnas.
#
# Algunas columnas tienen ":". Eliminalos de los nombres de las columnas.

# %%
col_anterior = list(df.columns)

# %%
col_anterior
# Out:
# ['Country',
#  'Density\n(P/Km2)',
#  'Abbreviation',
#  'Agricultural Land( %)',
#  'Land Area(Km2)',
#  'Armed Forces size',
#  'Birth Rate',
#  'Calling Code',
#  'Capital/Major City',
#  'Co2-Emissions',
#  'CPI',
#  'CPI Change (%)',
#  'Currency-Code',
#  'Fertility Rate',
#  'Forested Area (%)',
#  'Gasoline Price',
#  'GDP',
#  'Gross primary education enrollment (%)',
#  'Gross tertiary education enrollment (%)',
#  'Infant mortality',
#  'Largest city',
#  'Life expectancy',
#  'Maternal mortality ratio',
#  'Minimum wage',
#  'Official language',
#  'Out of pocket health expenditure',
#  'Physicians per thousand',
#  'Population',
#  'Population: Labor force participation (%)',
#  'Tax revenue (%)',
#  'Total tax rate',
#  'Unemployment rate',
#  'Urban_population',
#  'coordinates']

# %%
colum = []
for i in range(0, len(col_anterior)):
    try:
        col_anterior[i].replace(' ', '_')
    except:
        pass
    try:
        col_anterior = col_anterior[i].replace(':', '')
    except:
        pass
    try:
        col_anterior = col_anterior[i].replace('(%)', '')
    except:
        pass
    try:
        col_anterior = col_anterior[i].replace('(Km2)', '')
    except:
        pass
    try:
        col_anterior = col_anterior[i].replace('\n', '')
    except:
        pass
    try:
        col_anterior = col_anterior[i].strip()
    except:
        pass
    try:
        col_anterior = col_anterior[i].lower()
    except:
        pass

# %%
col_anterior
# Out:
# 'c'

# %%
df.rename(columns={'anterior': 'nuevo'}, inplace=True)

# %% [markdown]
# lo que ha hecho César:
#
# `columnas = df_final.columns`
#
# `nuevas_columnas = {col: col.split("(")[0].strip().replace(" ", "_").replace("\n", "").replace(":", "").lower() for col in columnas}`
#
# `df_final.rename(columns=nuevas_columnas, inplace = True)`

# %%
colum = {}
for col in df.columns:
    colum[col] = col.split('(')[0].replace(':', '').replace('\n', '').strip().replace(' ', '_').lower()

colum
# Out:
# {'Country': 'country',
#  'Density\n(P/Km2)': 'density',
#  'Abbreviation': 'abbreviation',
#  'Agricultural Land( %)': 'agricultural_land',
#  'Land Area(Km2)': 'land_area',
#  'Armed Forces size': 'armed_forces_size',
#  'Birth Rate': 'birth_rate',
#  'Calling Code': 'calling_code',
#  'Capital/Major City': 'capital/major_city',
#  'Co2-Emissions': 'co2-emissions',
#  'CPI': 'cpi',
#  'CPI Change (%)': 'cpi_change',
#  'Currency-Code': 'currency-code',
#  'Fertility Rate': 'fertility_rate',
#  'Forested Area (%)': 'forested_area',
#  'Gasoline Price': 'gasoline_price',
#  'GDP': 'gdp',
#  'Gross primary education enrollment (%)': 'gross_primary_education_enrollment',
#  'Gross tertiary education enrollment (%)': 'gross_tertiary_education_enrollment',
#  'Infant mortality': 'infant_mortality',
#  'Largest city': 'largest_city',
#  'Life expectancy': 'life_expectancy',
#  'Maternal mortality ratio': 'maternal_mortality_ratio',
#  'Minimum wage': 'minimum_wage',
# ...

# %%
df.rename(columns=colum, inplace = True)

# %%
df.head(1)
# Out:
#        country density abbreviation agricultural_land land_area  \
# 0  Afghanistan      60           AF            58.10%   652,230
#
#   armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0           323,000       32.49          93.0              Kabul
#
#   co2-emissions  ... official_language out_of_pocket_health_expenditure  \
# 0         8,672  ...            Pashto                           78.40%
#
#   physicians_per_thousand  population population_labor_force_participation  \
# 0                    0.28  38,041,754                               48.90%
#
#   tax_revenue total_tax_rate unemployment_rate urban_population  \
# 0       9.30%         71.40%            11.12%        9,797,273
#
#                   coordinates
# 0  ('33.93911 ', '67.709953')
#
# [1 rows x 34 columns]
